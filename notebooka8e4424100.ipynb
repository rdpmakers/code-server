# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !sudo apt update && sudo apt upgrade -y && sudo apt install git iputils-ping curl python2 -y
# !git clone http:/\/github.com/4L13199/LITEDDOS
# !cd LITEDDOS && chmod -R 777 *
# Out:
# Get:1 http://packages.cloud.google.com/apt gcsfuse-focal InRelease [5002 B]
# Get:2 https://packages.cloud.google.com/apt cloud-sdk InRelease [6361 B]
# Get:3 https://packages.cloud.google.com/apt google-fast-socket InRelease [5015 B]
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:8 https://packages.cloud.google.com/apt cloud-sdk/main amd64 Packages [445 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [108 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [360 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [360 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [918 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1157 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [512 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [794 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [49.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [27.0 kB]
# Fetched 4975 kB in 2s (2922 kB/s)
#
#
#
# 46 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: http://packages.cloud.google.com/apt/dists/gcsfuse-focal/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# W: https://packages.cloud.google.com/apt/dists/google-fast-socket/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
#
#
#
#
# The following packages have been kept back:
#   libcudnn8 libcudnn8-dev libnccl-dev libnccl2
# The following packages will be upgraded:
#   binutils binutils-common binutils-x86-64-linux-gnu ca-certificates cpp-11
#   dpkg dpkg-dev g++-11 gcc-11 gcc-11-base gcsfuse google-cloud-sdk libasan6
#   libbinutils libctf-nobfd0 libctf0 libdpkg-perl libgcc-11-dev
#   libgssapi-krb5-2 libk5crypto3 libkpathsea6 libkrb5-3 libkrb5support0
#   libncurses6 libncursesw6 libptexenc1 libssl-dev libssl3 libstdc++-11-dev
#   libsynctex2 libtexlua53 libtexluajit2 libtinfo6 libtsan0 libwebp7
#   linux-libc-dev ncurses-base ncurses-bin openssl python3-software-properties
#   software-properties-common texlive-binaries
# 42 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# Need to get 244 MB of archives.
# After this operation, 1270 kB disk space will be freed.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dpkg amd64 1.21.1ubuntu2.2 [1239 kB]
# Get:2 http://packages.cloud.google.com/apt gcsfuse-focal/main amd64 gcsfuse amd64 0.42.5 [14.0 MB]
# Get:3 https://packages.cloud.google.com/apt cloud-sdk/main amd64 google-cloud-sdk all 432.0.0-0 [154 MB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ncurses-bin amd64 6.3-2ubuntu0.1 [184 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ncurses-base all 6.3-2ubuntu0.1 [20.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libk5crypto3 amd64 1.19.2-2ubuntu0.2 [86.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libkrb5support0 amd64 1.19.2-2ubuntu0.2 [32.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libkrb5-3 amd64 1.19.2-2ubuntu0.2 [357 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgssapi-krb5-2 amd64 1.19.2-2ubuntu0.2 [145 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libncursesw6 amd64 6.3-2ubuntu0.1 [147 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libncurses6 amd64 6.3-2ubuntu0.1 [111 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtinfo6 amd64 6.3-2ubuntu0.1 [105 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ca-certificates all 20230311ubuntu0.22.04.1 [155 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 libssl-dev amd64 3.0.2-0ubuntu1.10 [2372 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libctf0 amd64 2.38-4ubuntu2.2 [103 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libctf-nobfd0 amd64 2.38-4ubuntu2.2 [107 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 binutils-x86-64-linux-gnu amd64 2.38-4ubuntu2.2 [2328 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 libssl3 amd64 3.0.2-0ubuntu1.10 [1901 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/main amd64 openssl amd64 3.0.2-0ubuntu1.10 [1183 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libbinutils amd64 2.38-4ubuntu2.2 [660 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 binutils amd64 2.38-4ubuntu2.2 [3186 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 binutils-common amd64 2.38-4ubuntu2.2 [222 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 g++-11 amd64 11.3.0-1ubuntu1~22.04.1 [11.4 MB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libstdc++-11-dev amd64 11.3.0-1ubuntu1~22.04.1 [2087 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libasan6 amd64 11.3.0-1ubuntu1~22.04.1 [2284 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gcc-11 amd64 11.3.0-1ubuntu1~22.04.1 [20.1 MB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgcc-11-dev amd64 11.3.0-1ubuntu1~22.04.1 [2516 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtsan0 amd64 11.3.0-1ubuntu1~22.04.1 [2260 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 cpp-11 amd64 11.3.0-1ubuntu1~22.04.1 [9968 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gcc-11-base amd64 11.3.0-1ubuntu1~22.04.1 [20.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dpkg-dev all 1.21.1ubuntu2.2 [922 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdpkg-perl all 1.21.1ubuntu2.2 [237 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libkpathsea6 amd64 2021.20210626.59705-1ubuntu0.1 [60.3 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 texlive-binaries amd64 2021.20210626.59705-1ubuntu0.1 [9848 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libptexenc1 amd64 2021.20210626.59705-1ubuntu0.1 [39.1 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsynctex2 amd64 2021.20210626.59705-1ubuntu0.1 [55.5 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtexlua53 amd64 2021.20210626.59705-1ubuntu0.1 [120 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtexluajit2 amd64 2021.20210626.59705-1ubuntu0.1 [267 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwebp7 amd64 1.2.2-2ubuntu0.22.04.1 [206 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 linux-libc-dev amd64 5.15.0-72.79 [1331 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 software-properties-common all 0.99.22.7 [14.1 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-software-properties all 0.99.22.7 [28.8 kB]
# Fetched 244 MB in 5s (51.6 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
#
# (Reading database ... 115376 files and directories currently installed.)
# Preparing to unpack .../dpkg_1.21.1ubuntu2.2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking dpkg (1.21.1ubuntu2.2) over (1.21.1ubuntu2.1) ...
# 7Progress: [  1%] [..........................................................] 8Setting up dpkg (1.21.1ubuntu2.2) ...
# (Reading database ... 115376 files and directories currently installed.)
# Preparing to unpack .../ncurses-bin_6.3-2ubuntu0.1_amd64.deb ...
# Unpacking ncurses-bin (6.3-2ubuntu0.1) over (6.3-2) ...
# 7Progress: [  4%] [##........................................................] 8Setting up ncurses-bin (6.3-2ubuntu0.1) ...
# (Reading database ... 115376 files and directories currently installed.)
# Preparing to unpack .../ncurses-base_6.3-2ubuntu0.1_all.deb ...
# 7Progress: [  5%] [###.......................................................] 8Unpacking ncurses-base (6.3-2ubuntu0.1) over (6.3-2) ...
# Setting up ncurses-base (6.3-2ubuntu0.1) ...
# (Reading database ... 115376 files and directories currently installed.)
# Preparing to unpack .../libk5crypto3_1.19.2-2ubuntu0.2_amd64.deb ...
# Unpacking libk5crypto3:amd64 (1.19.2-2ubuntu0.2) over (1.19.2-2ubuntu0.1) ...
# 7Progress: [  8%] [####......................................................] 8Setting up libk5crypto3:amd64 (1.19.2-2ubuntu0.2) ...
# (Reading database ... 115376 files and directories currently installed.)
# Preparing to unpack .../libkrb5support0_1.19.2-2ubuntu0.2_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libkrb5support0:amd64 (1.19.2-2ubuntu0.2) over (1.19.2-2ubuntu0.1) ...
# Setting up libkrb5support0:amd64 (1.19.2-2ubuntu0.2) ...
# (Reading database ... 115376 files and directories currently installed.)
# Preparing to unpack .../libkrb5-3_1.19.2-2ubuntu0.2_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libkrb5-3:amd64 (1.19.2-2ubuntu0.2) over (1.19.2-2ubuntu0.1) ...
# 7Progress: [ 13%] [#######...................................................] 8Setting up libkrb5-3:amd64 (1.19.2-2ubuntu0.2) ...
# (Reading database ... 115376 files and directories currently installed.)
# Preparing to unpack .../libgssapi-krb5-2_1.19.2-2ubuntu0.2_amd64.deb ...
# Unpacking libgssapi-krb5-2:amd64 (1.19.2-2ubuntu0.2) over (1.19.2-2ubuntu0.1) ...
# 7Progress: [ 15%] [########..................................................] 8Setting up libgssapi-krb5-2:amd64 (1.19.2-2ubuntu0.2) ...
# (Reading database ... 115376 files and directories currently installed.)
# Preparing to unpack .../libssl-dev_3.0.2-0ubuntu1.10_amd64.deb ...
# 7Progress: [ 17%] [#########.................................................] 8Unpacking libssl-dev:amd64 (3.0.2-0ubuntu1.10) over (3.0.2-0ubuntu1.9) ...
# Preparing to unpack .../libssl3_3.0.2-0ubuntu1.10_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libssl3:amd64 (3.0.2-0ubuntu1.10) over (3.0.2-0ubuntu1.9) ...
# Setting up libssl3:amd64 (3.0.2-0ubuntu1.10) ...
# (Reading database ... 115376 files and directories currently installed.)
# Preparing to unpack .../libncursesw6_6.3-2ubuntu0.1_amd64.deb ...
# Unpacking libncursesw6:amd64 (6.3-2ubuntu0.1) over (6.3-2) ...
# 7Progress: [ 21%] [############..............................................] 8Preparing to unpack .../libncurses6_6.3-2ubuntu0.1_amd64.deb ...
# Unpacking libncurses6:amd64 (6.3-2ubuntu0.1) over (6.3-2) ...
# 7Progress: [ 22%] [#############.............................................] 8Preparing to unpack .../libtinfo6_6.3-2ubuntu0.1_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libtinfo6:amd64 (6.3-2ubuntu0.1) over (6.3-2) ...
# Setting up libtinfo6:amd64 (6.3-2ubuntu0.1) ...
# (Reading database ... 115376 files and directories currently installed.)
# Preparing to unpack .../00-openssl_3.0.2-0ubuntu1.10_amd64.deb ...
# 7Progress: [ 25%] [##############............................................] 8Unpacking openssl (3.0.2-0ubuntu1.10) over (3.0.2-0ubuntu1.9) ...
# 7Progress: [ 26%] [###############...........................................] 8Preparing to unpack .../01-ca-certificates_20230311ubuntu0.22.04.1_all.deb ...
# Unpacking ca-certificates (20230311ubuntu0.22.04.1) over (20211016ubuntu0.22.04.1) ...
# 7Progress: [ 27%] [###############...........................................] 8Preparing to unpack .../02-libctf0_2.38-4ubuntu2.2_amd64.deb ...
# Unpacking libctf0:amd64 (2.38-4ubuntu2.2) over (2.38-4ubuntu2.1) ...
# 7Progress: [ 28%] [################..........................................] 8Preparing to unpack .../03-libctf-nobfd0_2.38-4ubuntu2.2_amd64.deb ...
# Unpacking libctf-nobfd0:amd64 (2.38-4ubuntu2.2) over (2.38-4ubuntu2.1) ...
# 7Progress: [ 30%] [#################.........................................] 8Preparing to unpack .../04-binutils-x86-64-linux-gnu_2.38-4ubuntu2.2_amd64.deb ...
# 7Progress: [ 30%] [#################.........................................] 8Unpacking binutils-x86-64-linux-gnu (2.38-4ubuntu2.2) over (2.38-4ubuntu2.1) ...
# Preparing to unpack .../05-libbinutils_2.38-4ubuntu2.2_amd64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking libbinutils:amd64 (2.38-4ubuntu2.2) over (2.38-4ubuntu2.1) ...
# Preparing to unpack .../06-binutils_2.38-4ubuntu2.2_amd64.deb ...
# 7Progress: [ 33%] [##################........................................] 8Unpacking binutils (2.38-4ubuntu2.2) over (2.38-4ubuntu2.1) ...
# 7Progress: [ 33%] [###################.......................................] 8Preparing to unpack .../07-binutils-common_2.38-4ubuntu2.2_amd64.deb ...
# Unpacking binutils-common:amd64 (2.38-4ubuntu2.2) over (2.38-4ubuntu2.1) ...
# 7Progress: [ 34%] [###################.......................................] 8Preparing to unpack .../08-g++-11_11.3.0-1ubuntu1~22.04.1_amd64.deb ...
# Unpacking g++-11 (11.3.0-1ubuntu1~22.04.1) over (11.3.0-1ubuntu1~22.04) ...
# 7Progress: [ 36%] [####################......................................] 8Preparing to unpack .../09-libstdc++-11-dev_11.3.0-1ubuntu1~22.04.1_amd64.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking libstdc++-11-dev:amd64 (11.3.0-1ubuntu1~22.04.1) over (11.3.0-1ubuntu1~22.04) ...
# Preparing to unpack .../10-libasan6_11.3.0-1ubuntu1~22.04.1_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libasan6:amd64 (11.3.0-1ubuntu1~22.04.1) over (11.3.0-1ubuntu1~22.04) ...
# Preparing to unpack .../11-gcc-11_11.3.0-1ubuntu1~22.04.1_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking gcc-11 (11.3.0-1ubuntu1~22.04.1) over (11.3.0-1ubuntu1~22.04) ...
# 7Progress: [ 39%] [######################....................................] 8Preparing to unpack .../12-libgcc-11-dev_11.3.0-1ubuntu1~22.04.1_amd64.deb ...
# Unpacking libgcc-11-dev:amd64 (11.3.0-1ubuntu1~22.04.1) over (11.3.0-1ubuntu1~22.04) ...
# 7Progress: [ 40%] [#######################...................................] 8Preparing to unpack .../13-libtsan0_11.3.0-1ubuntu1~22.04.1_amd64.deb ...
# Unpacking libtsan0:amd64 (11.3.0-1ubuntu1~22.04.1) over (11.3.0-1ubuntu1~22.04) ...
# 7Progress: [ 41%] [########################..................................] 8Preparing to unpack .../14-cpp-11_11.3.0-1ubuntu1~22.04.1_amd64.deb ...
# 7Progress: [ 42%] [########################..................................] 8Unpacking cpp-11 (11.3.0-1ubuntu1~22.04.1) over (11.3.0-1ubuntu1~22.04) ...
# Preparing to unpack .../15-gcc-11-base_11.3.0-1ubuntu1~22.04.1_amd64.deb ...
# 7Progress: [ 43%] [#########################.................................] 8Unpacking gcc-11-base:amd64 (11.3.0-1ubuntu1~22.04.1) over (11.3.0-1ubuntu1~22.04) ...
# Preparing to unpack .../16-dpkg-dev_1.21.1ubuntu2.2_all.deb ...
# 7Progress: [ 44%] [#########################.................................] 8Unpacking dpkg-dev (1.21.1ubuntu2.2) over (1.21.1ubuntu2.1) ...
# Preparing to unpack .../17-libdpkg-perl_1.21.1ubuntu2.2_all.deb ...
# 7Progress: [ 46%] [##########################................................] 8Unpacking libdpkg-perl (1.21.1ubuntu2.2) over (1.21.1ubuntu2.1) ...
# 7Progress: [ 46%] [##########################................................] 8Preparing to unpack .../18-gcsfuse_0.42.5_amd64.deb ...
# Unpacking gcsfuse (0.42.5) over (0.42.4) ...
# 7Progress: [ 47%] [###########################...............................] 8Preparing to unpack .../19-google-cloud-sdk_432.0.0-0_all.deb ...
# Unpacking google-cloud-sdk (432.0.0-0) over (429.0.0-0) ...
# 7Progress: [ 49%] [############################..............................] 8Preparing to unpack .../20-libkpathsea6_2021.20210626.59705-1ubuntu0.1_amd64.deb ...
# 7Progress: [ 49%] [############################..............................] 8Unpacking libkpathsea6:amd64 (2021.20210626.59705-1ubuntu0.1) over (2021.20210626.59705-1build1) ...
# Preparing to unpack .../21-texlive-binaries_2021.20210626.59705-1ubuntu0.1_amd64.deb ...
# 7Progress: [ 50%] [#############################.............................] 8Unpacking texlive-binaries (2021.20210626.59705-1ubuntu0.1) over (2021.20210626.59705-1build1) ...
# Preparing to unpack .../22-libptexenc1_2021.20210626.59705-1ubuntu0.1_amd64.deb ...
# 7Progress: [ 51%] [#############################.............................] 8Unpacking libptexenc1:amd64 (2021.20210626.59705-1ubuntu0.1) over (2021.20210626.59705-1build1) ...
# 7Progress: [ 52%] [##############################............................] 8Preparing to unpack .../23-libsynctex2_2021.20210626.59705-1ubuntu0.1_amd64.deb ...
# Unpacking libsynctex2:amd64 (2021.20210626.59705-1ubuntu0.1) over (2021.20210626.59705-1build1) ...
# 7Progress: [ 53%] [##############################............................] 8Preparing to unpack .../24-libtexlua53_2021.20210626.59705-1ubuntu0.1_amd64.deb ...
# Unpacking libtexlua53:amd64 (2021.20210626.59705-1ubuntu0.1) over (2021.20210626.59705-1build1) ...
# 7Progress: [ 54%] [###############################...........................] 8Preparing to unpack .../25-libtexluajit2_2021.20210626.59705-1ubuntu0.1_amd64.deb ...
# 7Progress: [ 55%] [###############################...........................] 8Unpacking libtexluajit2:amd64 (2021.20210626.59705-1ubuntu0.1) over (2021.20210626.59705-1build1) ...
# Preparing to unpack .../26-libwebp7_1.2.2-2ubuntu0.22.04.1_amd64.deb ...
# 7Progress: [ 56%] [################################..........................] 8Unpacking libwebp7:amd64 (1.2.2-2ubuntu0.22.04.1) over (1.2.2-2) ...
# Preparing to unpack .../27-linux-libc-dev_5.15.0-72.79_amd64.deb ...
# 7Progress: [ 57%] [#################################.........................] 8Unpacking linux-libc-dev:amd64 (5.15.0-72.79) over (5.15.0-71.78) ...
# Preparing to unpack .../28-software-properties-common_0.99.22.7_all.deb ...
# 7Progress: [ 59%] [#################################.........................] 8Unpacking software-properties-common (0.99.22.7) over (0.99.22.6) ...
# 7Progress: [ 59%] [##################################........................] 8Preparing to unpack .../29-python3-software-properties_0.99.22.7_all.deb ...
# Unpacking python3-software-properties (0.99.22.7) over (0.99.22.6) ...
# 7Progress: [ 60%] [###################################.......................] 8Setting up gcc-11-base:amd64 (11.3.0-1ubuntu1~22.04.1) ...
# 7Progress: [ 62%] [###################################.......................] 8Setting up gcsfuse (0.42.5) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libtexlua53:amd64 (2021.20210626.59705-1ubuntu0.1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libtexluajit2:amd64 (2021.20210626.59705-1ubuntu0.1) ...
# 7Progress: [ 64%] [#####################################.....................] 87Progress: [ 65%] [#####################################.....................] 8Setting up binutils-common:amd64 (2.38-4ubuntu2.2) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up linux-libc-dev:amd64 (5.15.0-72.79) ...
# 7Progress: [ 67%] [#######################################...................] 8Setting up libctf-nobfd0:amd64 (2.38-4ubuntu2.2) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libasan6:amd64 (11.3.0-1ubuntu1~22.04.1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up python3-software-properties (0.99.22.7) ...
# 7Progress: [ 70%] [########################################..................] 87Progress: [ 71%] [#########################################.................] 8Setting up libncurses6:amd64 (6.3-2ubuntu0.1) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libssl-dev:amd64 (3.0.2-0ubuntu1.10) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libncursesw6:amd64 (6.3-2ubuntu0.1) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libdpkg-perl (1.21.1ubuntu2.2) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libkpathsea6:amd64 (2021.20210626.59705-1ubuntu0.1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libwebp7:amd64 (1.2.2-2ubuntu0.22.04.1) ...
# 7Progress: [ 78%] [############################################..............] 87Progress: [ 78%] [#############################################.............] 8Setting up google-cloud-sdk (432.0.0-0) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libbinutils:amd64 (2.38-4ubuntu2.2) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up openssl (3.0.2-0ubuntu1.10) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libsynctex2:amd64 (2021.20210626.59705-1ubuntu0.1) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libtsan0:amd64 (11.3.0-1ubuntu1~22.04.1) ...
# 7Progress: [ 83%] [################################################..........] 87Progress: [ 84%] [################################################..........] 8Setting up libctf0:amd64 (2.38-4ubuntu2.2) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up cpp-11 (11.3.0-1ubuntu1~22.04.1) ...
# 7Progress: [ 86%] [##################################################........] 8Setting up ca-certificates (20230311ubuntu0.22.04.1) ...
# Updating certificates in /etc/ssl/certs...
# rehash: warning: skipping ca-certificates.crt,it does not contain exactly one certificate or CRL
# 19 added, 6 removed; done.
# 7Progress: [ 88%] [##################################################........] 8Setting up libptexenc1:amd64 (2021.20210626.59705-1ubuntu0.1) ...
# Setting up libgcc-11-dev:amd64 (11.3.0-1ubuntu1~22.04.1) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up texlive-binaries (2021.20210626.59705-1ubuntu0.1) ...
# 7Progress: [ 89%] [###################################################.......] 87Progress: [ 90%] [####################################################......] 8Setting up binutils-x86-64-linux-gnu (2.38-4ubuntu2.2) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up binutils (2.38-4ubuntu2.2) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up software-properties-common (0.99.22.7) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up dpkg-dev (1.21.1ubuntu2.2) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libstdc++-11-dev:amd64 (11.3.0-1ubuntu1~22.04.1) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up gcc-11 (11.3.0-1ubuntu1~22.04.1) ...
# 7Progress: [ 96%] [#######################################################...] 87Progress: [ 97%] [########################################################..] 8Setting up g++-11 (11.3.0-1ubuntu1~22.04.1) ...
# 7Progress: [ 98%] [########################################################..] 8Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for install-info (6.8-4build1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# Processing triggers for ca-certificates (20230311ubuntu0.22.04.1) ...
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Running hooks in /etc/ca-certificates/update.d...
#
# done.
# done.
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for tex-common (6.17) ...
# Building format(s) --all.
# 	This may take some time... done.
#
#
#
#
# curl is already the newest version (7.81.0-1ubuntu1.10).
# git is already the newest version (1:2.34.1-1ubuntu1.9).
# The following additional packages will be installed:
#   libpython2-stdlib libpython2.7-minimal libpython2.7-stdlib python2-minimal
#   python2.7 python2.7-minimal
# Suggested packages:
#   python2-doc python-tk python2.7-doc binfmt-support
# The following NEW packages will be installed:
#   iputils-ping libpython2-stdlib libpython2.7-minimal libpython2.7-stdlib
#   python2 python2-minimal python2.7 python2.7-minimal
# 0 upgraded, 8 newly installed, 0 to remove and 4 not upgraded.
# Need to get 4048 kB of archives.
# After this operation, 16.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libpython2.7-minimal amd64 2.7.18-13ubuntu1.1 [347 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python2.7-minimal amd64 2.7.18-13ubuntu1.1 [1394 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python2-minimal amd64 2.7.18-3 [20.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libpython2.7-stdlib amd64 2.7.18-13ubuntu1.1 [1977 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python2.7 amd64 2.7.18-13ubuntu1.1 [250 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpython2-stdlib amd64 2.7.18-3 [7432 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python2 amd64 2.7.18-3 [9098 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 iputils-ping amd64 3:20211215-1 [42.9 kB]
# Fetched 4048 kB in 1s (4090 kB/s)
#
# 78Selecting previously unselected package libpython2.7-minimal:amd64.
# (Reading database ... 115547 files and directories currently installed.)
# Preparing to unpack .../0-libpython2.7-minimal_2.7.18-13ubuntu1.1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  3%] [#.........................................................] 8Unpacking libpython2.7-minimal:amd64 (2.7.18-13ubuntu1.1) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package python2.7-minimal.
# Preparing to unpack .../1-python2.7-minimal_2.7.18-13ubuntu1.1_amd64.deb ...
# 7Progress: [  9%] [#####.....................................................] 8Unpacking python2.7-minimal (2.7.18-13ubuntu1.1) ...
# 7Progress: [ 12%] [#######...................................................] 8Selecting previously unselected package python2-minimal.
# Preparing to unpack .../2-python2-minimal_2.7.18-3_amd64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking python2-minimal (2.7.18-3) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package libpython2.7-stdlib:amd64.
# Preparing to unpack .../3-libpython2.7-stdlib_2.7.18-13ubuntu1.1_amd64.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking libpython2.7-stdlib:amd64 (2.7.18-13ubuntu1.1) ...
# 7Progress: [ 24%] [##############............................................] 8Selecting previously unselected package python2.7.
# Preparing to unpack .../4-python2.7_2.7.18-13ubuntu1.1_amd64.deb ...
# 7Progress: [ 27%] [###############...........................................] 8Unpacking python2.7 (2.7.18-13ubuntu1.1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libpython2-stdlib:amd64.
# Preparing to unpack .../5-libpython2-stdlib_2.7.18-3_amd64.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking libpython2-stdlib:amd64 (2.7.18-3) ...
# 7Progress: [ 36%] [#####################.....................................] 8Setting up libpython2.7-minimal:amd64 (2.7.18-13ubuntu1.1) ...
# 7Progress: [ 39%] [######################....................................] 87Progress: [ 42%] [########################..................................] 8Setting up python2.7-minimal (2.7.18-13ubuntu1.1) ...
# 7Progress: [ 45%] [##########################................................] 8Linking and byte-compiling packages for runtime python2.7...
# 7Progress: [ 48%] [############################..............................] 8Setting up python2-minimal (2.7.18-3) ...
# 7Progress: [ 52%] [#############################.............................] 87Progress: [ 55%] [###############################...........................] 8Selecting previously unselected package python2.
# (Reading database ... 116290 files and directories currently installed.)
# Preparing to unpack .../python2_2.7.18-3_amd64.deb ...
# 7Progress: [ 58%] [#################################.........................] 8Unpacking python2 (2.7.18-3) ...
# 7Progress: [ 61%] [###################################.......................] 8Selecting previously unselected package iputils-ping.
# Preparing to unpack .../iputils-ping_3%3a20211215-1_amd64.deb ...
# 7Progress: [ 64%] [####################################......................] 8Unpacking iputils-ping (3:20211215-1) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up libpython2.7-stdlib:amd64 (2.7.18-13ubuntu1.1) ...
# 7Progress: [ 70%] [########################################..................] 87Progress: [ 73%] [##########################################................] 8Setting up iputils-ping (3:20211215-1) ...
# 7Progress: [ 76%] [###########################################...............] 87Progress: [ 79%] [#############################################.............] 8Setting up python2.7 (2.7.18-13ubuntu1.1) ...
# 7Progress: [ 82%] [###############################################...........] 87Progress: [ 85%] [#################################################.........] 8Setting up libpython2-stdlib:amd64 (2.7.18-3) ...
# 7Progress: [ 88%] [##################################################........] 87Progress: [ 91%] [####################################################......] 8Setting up python2 (2.7.18-3) ...
# 7Progress: [ 94%] [######################################################....] 87Progress: [ 97%] [########################################################..] 8Processing triggers for man-db (2.10.2-1) ...
#
# 78Cloning into 'LITEDDOS'...
# warning: redirecting to https://github.com/4L13199/LITEDDOS/
# remote: Enumerating objects: 8, done.
# remote: Total 8 (delta 0), reused 0 (delta 0), pack-reused 8
# Receiving objects: 100% (8/8), 6.66 KiB | 1.33 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
